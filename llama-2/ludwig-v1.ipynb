# %%
# !pip uninstall -y tensorflow --quiet
# !pip install ludwig
# !pip install ludwig[llm]
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# Collecting ludwig
#   Downloading ludwig-0.8.6.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Cython>=0.25 (from ludwig)
#   Downloading Cython-3.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting h5py!=3.0.0,>=2.6 (from ludwig)
#   Downloading h5py-3.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.15 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (1.26.2)
# Requirement already satisfied: pandas!=1.1.5,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (2.1.3)
# Requirement already satisfied: scipy>=0.18 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (1.11.3)
# Collecting tabulate>=0.7 (from ludwig)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: scikit-learn in /opt/app-root/lib/python3.9/site-packages (from ludwig) (1.3.2)
# Requirement already satisfied: tqdm in /opt/app-root/lib/python3.9/site-packages (from ludwig) (4.66.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (2.1.0)
# Collecting torchaudio (from ludwig)
#   Downloading torchaudio-2.1.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchtext (from ludwig)
#   Downloading torchtext-0.16.1-cp39-cp39-manylinux1_x86_64.whl.metadata (7.5 kB)
# Collecting torchvision (from ludwig)
#   Downloading torchvision-0.16.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting pydantic<2.0 (from ludwig)
#   Downloading pydantic-1.10.13-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 252.9 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.33.2 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (4.36.0.dev0)
# Requirement already satisfied: tokenizers>=0.13.3 in /opt/app-root/lib/python3.9/site-packages (from ludwig) (0.14.1)
# Collecting spacy>=2.3 (from ludwig)
#   Downloading spacy-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting PyYAML!=5.4.*,<6.0.1,>=3.12 (from ludwig)
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 kB 58.9 MB/s eta 0:00:00
# Collecting absl-py (from ludwig)
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting kaggle (from ludwig)
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 228.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from ludwig) (2.31.0)
# Requirement already satisfied: fsspec[http] in /opt/app-root/lib/python3.9/site-packages (from ludwig) (2023.10.0)
# Collecting dataclasses-json (from ludwig)
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl.metadata (25 kB)
# Collecting jsonschema<4.7,>=4.5.0 (from ludwig)
#   Downloading jsonschema-4.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 214.2 MB/s eta 0:00:00
# Collecting marshmallow (from ludwig)
#   Downloading marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting marshmallow-jsonschema (from ludwig)
#   Downloading marshmallow_jsonschema-0.13.0-py3-none-any.whl (11 kB)
# Collecting marshmallow-dataclass==8.5.4 (from ludwig)
#   Downloading marshmallow_dataclass-8.5.4-py3-none-any.whl (16 kB)
# Collecting tensorboard (from ludwig)
#   Downloading tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nltk (from ludwig)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.1 MB/s eta 0:00:00
# Collecting torchmetrics<=0.11.4,>=0.11.0 (from ludwig)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 46.9 MB/s eta 0:00:00
# Collecting torchinfo (from ludwig)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from ludwig) (3.13.1)
# Collecting psutil==5.9.4 (from ludwig)
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 57.4 MB/s eta 0:00:00
# Collecting protobuf==3.20.3 (from ludwig)
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.0 MB/s eta 0:00:00
# Collecting py-cpuinfo==9.0.0 (from ludwig)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting gpustat (from ludwig)
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 231.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rich~=12.4.4 (from ludwig)
#   Downloading rich-12.4.4-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 87.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from ludwig) (23.1)
# Collecting retry (from ludwig)
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Collecting sacremoses (from ludwig)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting sentencepiece (from ludwig)
#   Downloading sentencepiece-0.1.99-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.2 MB/s eta 0:00:00
# Collecting getdaft (from ludwig)
#   Downloading getdaft-0.2.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting bitsandbytes<0.41.0 (from ludwig)
#   Downloading bitsandbytes-0.40.2-py3-none-any.whl.metadata (9.8 kB)
# Collecting xlwt (from ludwig)
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 236.8 MB/s eta 0:00:00
# Collecting xlrd>=2.0.1 (from ludwig)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 246.9 MB/s eta 0:00:00
# Collecting xlsxwriter>=1.4.3 (from ludwig)
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl.metadata (2.6 kB)
# Collecting openpyxl>=3.0.7 (from ludwig)
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 58.1 MB/s eta 0:00:00
# Collecting pyxlsb>=1.0.8 (from ludwig)
#   Downloading pyxlsb-1.0.10-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyarrow in /opt/app-root/lib/python3.9/site-packages (from ludwig) (14.0.1)
# Collecting lxml (from ludwig)
#   Downloading lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting html5lib (from ludwig)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 79.8 MB/s eta 0:00:00
# Collecting typing-inspect>=0.7.1 (from marshmallow-dataclass==8.5.4->ludwig)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.9/site-packages (from jsonschema<4.7,>=4.5.0->ludwig) (23.1.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.7,>=4.5.0->ludwig)
#   Downloading pyrsistent-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting et-xmlfile (from openpyxl>=3.0.7->ludwig)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/app-root/lib/python3.9/site-packages (from pydantic<2.0->ludwig) (4.7.1)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich~=12.4.4->ludwig)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 199.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/app-root/lib/python3.9/site-packages (from rich~=12.4.4->ludwig) (2.16.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=2.3->ludwig)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=2.3->ludwig)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=2.3->ludwig)
#   Downloading murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=2.3->ludwig)
#   Downloading cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=2.3->ludwig)
#   Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy>=2.3->ludwig)
#   Downloading thinc-8.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=2.3->ludwig)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=2.3->ludwig)
#   Downloading srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=2.3->ludwig)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy>=2.3->ludwig)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy>=2.3->ludwig)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 139.8 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy>=2.3->ludwig)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig) (3.1.2)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig) (53.0.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy>=2.3->ludwig)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 74.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig) (2023.7.22)
# Requirement already satisfied: huggingface_hub<0.18,>=0.16.4 in /opt/app-root/lib/python3.9/site-packages (from tokenizers>=0.13.3->ludwig) (0.17.3)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (1.12)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->ludwig) (12.3.52)
# Requirement already satisfied: regex!=2019.12.17 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.33.2->ludwig) (2023.10.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.33.2->ludwig) (0.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/app-root/lib/python3.9/site-packages (from fsspec[http]->ludwig) (3.8.5)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat->ludwig)
#   Downloading nvidia_ml_py-12.535.133-py3-none-any.whl.metadata (8.6 kB)
# Collecting blessed>=1.17.1 (from gpustat->ludwig)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 216.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9 in /opt/app-root/lib/python3.9/site-packages (from html5lib->ludwig) (1.16.0)
# Requirement already satisfied: webencodings in /opt/app-root/lib/python3.9/site-packages (from html5lib->ludwig) (0.5.1)
# Collecting python-slugify (from kaggle->ludwig)
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: bleach in /opt/app-root/lib/python3.9/site-packages (from kaggle->ludwig) (6.0.0)
# Collecting click (from nltk->ludwig)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in /opt/app-root/lib/python3.9/site-packages (from nltk->ludwig) (1.3.2)
# Requirement already satisfied: decorator>=3.4.2 in /opt/app-root/lib/python3.9/site-packages (from retry->ludwig) (5.1.1)
# Collecting py<2.0.0,>=1.4.26 (from retry->ludwig)
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 203.9 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from scikit-learn->ludwig) (3.2.0)
# Collecting grpcio>=1.48.2 (from tensorboard->ludwig)
#   Downloading grpcio-1.59.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard->ludwig)
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard->ludwig)
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard->ludwig)
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->ludwig)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->ludwig)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting torch>=1.13.0 (from ludwig)
#   Downloading torch-2.1.1-cp39-cp39-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchdata==0.7.1 (from torchtext->ludwig)
#   Downloading torchdata-0.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/app-root/lib/python3.9/site-packages (from torchvision->ludwig) (10.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig) (1.3.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/app-root/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->ludwig) (0.2.6)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard->ludwig)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard->ludwig)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 117.7 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard->ludwig)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard->ludwig)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->ludwig) (6.8.0)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy>=2.3->ludwig)
#   Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy>=2.3->ludwig)
#   Downloading confection-0.1.3-py3-none-any.whl.metadata (19 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.7.1->marshmallow-dataclass==8.5.4->ludwig)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy>=2.3->ludwig)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/app-root/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->ludwig) (2.1.3)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle->ludwig)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 218.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch>=1.13.0->ludwig) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->ludwig) (3.16.2)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->ludwig)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 222.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->ludwig)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 256.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.40.2-py3-none-any.whl (92.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 41.4 MB/s eta 0:00:0000:0100:01
# Downloading Cython-3.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 33.9 MB/s eta 0:00:00a 0:00:01
# Downloading h5py-3.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 40.1 MB/s eta 0:00:00a 0:00:01
# Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 93.2 MB/s eta 0:00:00
# Downloading pydantic-1.10.13-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 39.8 MB/s eta 0:00:00a 0:00:01
# Downloading spacy-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 40.5 MB/s eta 0:00:00a 0:00:01
# Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 131.5 MB/s eta 0:00:00
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 149.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Downloading getdaft-0.2.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 30.1 MB/s eta 0:00:00a 0:00:01
# Downloading lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 39.9 MB/s eta 0:00:00a 0:00:01
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 48.1 MB/s eta 0:00:00
# Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 41.5 MB/s eta 0:00:00a 0:00:01
# Downloading torchaudio-2.1.1-cp39-cp39-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 41.8 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.1.1-cp39-cp39-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 39.2 MB/s eta 0:00:0000:0100:01
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading torchtext-0.16.1-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 45.2 MB/s eta 0:00:00a 0:00:01
# Downloading torchdata-0.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 40.2 MB/s eta 0:00:00a 0:00:01
# Downloading torchvision-0.16.1-cp39-cp39-manylinux1_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 40.2 MB/s eta 0:00:00a 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 206.6 MB/s eta 0:00:00
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 174.1 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading grpcio-1.59.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 38.0 MB/s eta 0:00:00a 0:00:01
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 243.1 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Downloading nvidia_ml_py-12.535.133-py3-none-any.whl (37 kB)
# Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.5/157.5 kB 146.1 MB/s eta 0:00:00
# Downloading pyrsistent-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 13.7 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 190.6 MB/s eta 0:00:00
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 47.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 39.3 MB/s eta 0:00:00a 0:00:01
# Downloading thinc-8.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (936 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.0/936.0 kB 47.0 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 152.8 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 152.0 MB/s eta 0:00:00
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 88.4 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 38.9 MB/s eta 0:00:00 0:00:01
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 212.2 MB/s eta 0:00:00
# Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Building wheels for collected packages: ludwig, gpustat, kaggle
#   Building wheel for ludwig (pyproject.toml) ... done
#   Created wheel for ludwig: filename=ludwig-0.8.6-py3-none-any.whl size=1093532 sha256=ab9179d4643f52a4f82333361ebcd5aa22a7b19fe94638878367327b5e679ca0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n0sp8pxo/wheels/fb/3f/c5/c1fefd1ef11977705bcc217f338d0f648a89d46ca86cfdcb24
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26535 sha256=0209af8685273f6751f02ac1636a3939562eda1e4d3814706087474a5ab6c224
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n0sp8pxo/wheels/12/7d/d7/444dca5ad3c5ea8c4e00ff211673505e0214fa9b0303dbd3b6
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110701 sha256=df8bd590e853d4bbf6060124ad24704188a1d79064af95ec569fb67556219ba7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n0sp8pxo/wheels/d2/ed/a5/da3a0cfb13373d1ace41cafa4f2467d858c55c52473ba72799
# Successfully built ludwig gpustat kaggle
# Installing collected packages: xlwt, text-unidecode, sentencepiece, pyxlsb, py-cpuinfo, nvidia-ml-py, cymem, commonmark, bitsandbytes, xlsxwriter, xlrd, werkzeug, wasabi, torchinfo, tensorboard-data-server, tabulate, spacy-loggers, spacy-legacy, smart-open, rich, PyYAML, python-slugify, pyrsistent, pydantic, pyasn1, py, psutil, protobuf, oauthlib, mypy-extensions, murmurhash, marshmallow, lxml, langcodes, html5lib, h5py, grpcio, et-xmlfile, Cython, cloudpathlib, click, catalogue, cachetools, blis, blessed, absl-py, typing-inspect, typer, srsly, sacremoses, rsa, retry, requests-oauthlib, pyasn1-modules, preshed, openpyxl, nltk, marshmallow-jsonschema, markdown, kaggle, jsonschema, gpustat, torch, marshmallow-dataclass, google-auth, dataclasses-json, confection, weasel, torchvision, torchmetrics, torchdata, torchaudio, thinc, google-auth-oauthlib, getdaft, torchtext, tensorboard, spacy, ludwig
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.41.2.post2
#     Uninstalling bitsandbytes-0.41.2.post2:
#       Successfully uninstalled bitsandbytes-0.41.2.post2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.6.0
#     Uninstalling rich-13.6.0:
#       Successfully uninstalled rich-13.6.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.0
#     Uninstalling jsonschema-4.19.0:
#       Successfully uninstalled jsonschema-4.19.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0
#     Uninstalling torch-2.1.0:
#       Successfully uninstalled torch-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-events 0.7.0 requires jsonschema[format-nongpl]>=4.18.0, but you have jsonschema 4.6.2 which is incompatible.
# jupyterlab-server 2.24.0 requires jsonschema>=4.17.3, but you have jsonschema 4.6.2 which is incompatible.
# Successfully installed Cython-3.0.5 PyYAML-6.0 absl-py-2.0.0 bitsandbytes-0.40.2 blessed-1.20.0 blis-0.7.11 cachetools-5.3.2 catalogue-2.0.10 click-8.1.7 cloudpathlib-0.16.0 commonmark-0.9.1 confection-0.1.3 cymem-2.0.8 dataclasses-json-0.6.2 et-xmlfile-1.1.0 getdaft-0.2.2 google-auth-2.23.4 google-auth-oauthlib-1.1.0 gpustat-1.1.1 grpcio-1.59.2 h5py-3.10.0 html5lib-1.1 jsonschema-4.6.2 kaggle-1.5.16 langcodes-3.3.0 ludwig-0.8.6 lxml-4.9.3 markdown-3.5.1 marshmallow-3.20.1 marshmallow-dataclass-8.5.4 marshmallow-jsonschema-0.13.0 murmurhash-1.0.10 mypy-extensions-1.0.0 nltk-3.8.1 nvidia-ml-py-12.535.133 oauthlib-3.2.2 openpyxl-3.1.2 preshed-3.0.9 protobuf-3.20.3 psutil-5.9.4 py-1.11.0 py-cpuinfo-9.0.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 pydantic-1.10.13 pyrsistent-0.20.0 python-slugify-8.0.1 pyxlsb-1.0.10 requests-oauthlib-1.3.1 retry-0.9.2 rich-12.4.4 rsa-4.9 sacremoses-0.1.1 sentencepiece-0.1.99 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 tabulate-0.9.0 tensorboard-2.15.1 tensorboard-data-server-0.7.2 text-unidecode-1.3 thinc-8.2.1 torch-2.1.1 torchaudio-2.1.1 torchdata-0.7.1 torchinfo-1.8.0 torchmetrics-0.11.4 torchtext-0.16.1 torchvision-0.16.1 typer-0.9.0 typing-inspect-0.9.0 wasabi-1.1.2 weasel-0.3.4 werkzeug-3.0.1 xlrd-2.0.1 xlsxwriter-3.1.9 xlwt-1.3.0
# Requirement already satisfied: ludwig[llm] in /opt/app-root/lib/python3.9/site-packages (0.8.6)
# Requirement already satisfied: Cython>=0.25 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.0.5)
# Requirement already satisfied: h5py!=3.0.0,>=2.6 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.10.0)
# Requirement already satisfied: numpy>=1.15 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.26.2)
# Requirement already satisfied: pandas!=1.1.5,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.1.3)
# Requirement already satisfied: scipy>=0.18 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.11.3)
# Requirement already satisfied: tabulate>=0.7 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.9.0)
# Requirement already satisfied: scikit-learn in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.3.2)
# Requirement already satisfied: tqdm in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (4.66.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.1.1)
# Requirement already satisfied: torchaudio in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.1.1)
# Requirement already satisfied: torchtext in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.16.1)
# Requirement already satisfied: torchvision in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.16.1)
# Requirement already satisfied: pydantic<2.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.10.13)
# Requirement already satisfied: transformers>=4.33.2 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (4.36.0.dev0)
# Requirement already satisfied: tokenizers>=0.13.3 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.14.1)
# Requirement already satisfied: spacy>=2.3 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.7.2)
# Requirement already satisfied: PyYAML!=5.4.*,<6.0.1,>=3.12 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (6.0)
# Requirement already satisfied: absl-py in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.0.0)
# Requirement already satisfied: kaggle in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.5.16)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.31.0)
# Requirement already satisfied: fsspec[http] in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2023.10.0)
# Requirement already satisfied: dataclasses-json in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.6.2)
# Requirement already satisfied: jsonschema<4.7,>=4.5.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (4.6.2)
# Requirement already satisfied: marshmallow in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.20.1)
# Requirement already satisfied: marshmallow-jsonschema in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.13.0)
# Requirement already satisfied: marshmallow-dataclass==8.5.4 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (8.5.4)
# Requirement already satisfied: tensorboard in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.15.1)
# Requirement already satisfied: nltk in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.8.1)
# Requirement already satisfied: torchmetrics<=0.11.4,>=0.11.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.11.4)
# Requirement already satisfied: torchinfo in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.8.0)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.13.1)
# Requirement already satisfied: psutil==5.9.4 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (5.9.4)
# Requirement already satisfied: protobuf==3.20.3 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.20.3)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (9.0.0)
# Requirement already satisfied: gpustat in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.1.1)
# Requirement already satisfied: rich~=12.4.4 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (12.4.4)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (23.1)
# Requirement already satisfied: retry in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.9.2)
# Requirement already satisfied: sacremoses in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.1.1)
# Requirement already satisfied: sentencepiece in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.1.99)
# Requirement already satisfied: getdaft in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.2.2)
# Requirement already satisfied: bitsandbytes<0.41.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.40.2)
# Requirement already satisfied: xlwt in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.3.0)
# Requirement already satisfied: xlrd>=2.0.1 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (2.0.1)
# Requirement already satisfied: xlsxwriter>=1.4.3 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.1.9)
# Requirement already satisfied: openpyxl>=3.0.7 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (3.1.2)
# Requirement already satisfied: pyxlsb>=1.0.8 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.0.10)
# Requirement already satisfied: pyarrow in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (14.0.1)
# Requirement already satisfied: lxml in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (4.9.3)
# Requirement already satisfied: html5lib in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (1.1)
# Collecting sentence-transformers (from ludwig[llm])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting faiss-cpu (from ludwig[llm])
#   Downloading faiss_cpu-1.7.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 19.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: accelerate in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.25.0.dev0)
# Collecting loralib (from ludwig[llm])
#   Downloading loralib-0.1.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: peft>=0.4.0 in /opt/app-root/lib/python3.9/site-packages (from ludwig[llm]) (0.6.3.dev0)
# Requirement already satisfied: typing-inspect>=0.7.1 in /opt/app-root/lib/python3.9/site-packages (from marshmallow-dataclass==8.5.4->ludwig[llm]) (0.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.9/site-packages (from jsonschema<4.7,>=4.5.0->ludwig[llm]) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/app-root/lib/python3.9/site-packages (from jsonschema<4.7,>=4.5.0->ludwig[llm]) (0.20.0)
# Requirement already satisfied: et-xmlfile in /opt/app-root/lib/python3.9/site-packages (from openpyxl>=3.0.7->ludwig[llm]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig[llm]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig[llm]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/app-root/lib/python3.9/site-packages (from pandas!=1.1.5,>=1.0->ludwig[llm]) (2023.3)
# Requirement already satisfied: safetensors in /opt/app-root/lib/python3.9/site-packages (from peft>=0.4.0->ludwig[llm]) (0.4.0)
# Requirement already satisfied: huggingface-hub in /opt/app-root/lib/python3.9/site-packages (from accelerate->ludwig[llm]) (0.17.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/app-root/lib/python3.9/site-packages (from pydantic<2.0->ludwig[llm]) (4.7.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/app-root/lib/python3.9/site-packages (from rich~=12.4.4->ludwig[llm]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/app-root/lib/python3.9/site-packages (from rich~=12.4.4->ludwig[llm]) (2.16.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (6.4.0)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (3.1.2)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (53.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/app-root/lib/python3.9/site-packages (from spacy>=2.3->ludwig[llm]) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig[llm]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig[llm]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig[llm]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->ludwig[llm]) (2023.7.22)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (1.12)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.13.0->ludwig[llm]) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->ludwig[llm]) (12.3.52)
# Requirement already satisfied: regex!=2019.12.17 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.33.2->ludwig[llm]) (2023.10.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/app-root/lib/python3.9/site-packages (from fsspec[http]->ludwig[llm]) (3.8.5)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /opt/app-root/lib/python3.9/site-packages (from gpustat->ludwig[llm]) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in /opt/app-root/lib/python3.9/site-packages (from gpustat->ludwig[llm]) (1.20.0)
# Requirement already satisfied: six>=1.9 in /opt/app-root/lib/python3.9/site-packages (from html5lib->ludwig[llm]) (1.16.0)
# Requirement already satisfied: webencodings in /opt/app-root/lib/python3.9/site-packages (from html5lib->ludwig[llm]) (0.5.1)
# Requirement already satisfied: python-slugify in /opt/app-root/lib/python3.9/site-packages (from kaggle->ludwig[llm]) (8.0.1)
# Requirement already satisfied: bleach in /opt/app-root/lib/python3.9/site-packages (from kaggle->ludwig[llm]) (6.0.0)
# Requirement already satisfied: click in /opt/app-root/lib/python3.9/site-packages (from nltk->ludwig[llm]) (8.1.7)
# Requirement already satisfied: joblib in /opt/app-root/lib/python3.9/site-packages (from nltk->ludwig[llm]) (1.3.2)
# Requirement already satisfied: decorator>=3.4.2 in /opt/app-root/lib/python3.9/site-packages (from retry->ludwig[llm]) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/app-root/lib/python3.9/site-packages (from retry->ludwig[llm]) (1.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from scikit-learn->ludwig[llm]) (3.2.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from tensorboard->ludwig[llm]) (3.0.1)
# Requirement already satisfied: torchdata==0.7.1 in /opt/app-root/lib/python3.9/site-packages (from torchtext->ludwig[llm]) (0.7.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/app-root/lib/python3.9/site-packages (from torchvision->ludwig[llm]) (10.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig[llm]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig[llm]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig[llm]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig[llm]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/app-root/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]->ludwig[llm]) (1.3.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/app-root/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat->ludwig[llm]) (0.2.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig[llm]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig[llm]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->ludwig[llm]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->ludwig[llm]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->ludwig[llm]) (6.8.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/app-root/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.3->ludwig[llm]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/app-root/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.3->ludwig[llm]) (0.1.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/app-root/lib/python3.9/site-packages (from typing-inspect>=0.7.1->marshmallow-dataclass==8.5.4->ludwig[llm]) (1.0.0)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/app-root/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.3->ludwig[llm]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/app-root/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->ludwig[llm]) (2.1.3)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/app-root/lib/python3.9/site-packages (from python-slugify->kaggle->ludwig[llm]) (1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch>=1.13.0->ludwig[llm]) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->ludwig[llm]) (3.16.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/app-root/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->ludwig[llm]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->ludwig[llm]) (3.2.2)
# Downloading loralib-0.1.2-py3-none-any.whl (10 kB)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=a7052c1881275a05b1e7dfe6be6e7f3d06a54aa1adbcde0ec007831c28baa0b4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ms9yg5w5/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: faiss-cpu, loralib, sentence-transformers
# Successfully installed faiss-cpu-1.7.4 loralib-0.1.2 sentence-transformers-2.2.2

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))

get_ipython().events.register('pre_run_cell', set_css)

def clear_cache():
  if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
import getpass
import locale; locale.getpreferredencoding = lambda: "UTF-8"
import logging
import os
import torch
import yaml

from ludwig.api import LudwigModel
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 import logging
#       4 import os
# ----> 5 import torch
#       6 import yaml
#       8 from ludwig.api import LudwigModel
#
# File /opt/app-root/lib64/python3.9/site-packages/torch/__init__.py:465
#     451         raise ImportError(textwrap.dedent('''
#     452             Failed to load PyTorch C extensions:
#     453                 It appears that PyTorch has loaded the `torch/_C` folder
#    (...)
#     461                 or by running Python from a different directory.
#     462             ''').strip()) from None
#     463     raise  # If __file__ is not None the cause is unknown, so just re-raise.
# --> 465 for name in dir(_C):
#     466     if name[0] != '_' and not name.endswith('Base'):
#     467         __all__.append(name)
#
# NameError: name '_C' is not defined
